# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import networkx as nx
from textwrap import wrap

# %% [markdown]
# # Load data

# %%
order_products_train = pd.read_csv('instacart/order_products__train.csv')
order_products_prior = pd.read_csv('instacart/order_products__prior.csv')
orders = pd.read_csv('instacart/orders.csv')
products = pd.read_csv('instacart/products.csv')
aisles = pd.read_csv('instacart/aisles.csv')
departments = pd.read_csv('instacart/departments.csv')

# %%
print(order_products_train.shape)
order_products_train.head()
# Out:
# (1384617, 4)
#    order_id  product_id  add_to_cart_order  reordered
# 0         1       49302                  1          1
# 1         1       11109                  2          1
# 2         1       10246                  3          0
# 3         1       49683                  4          0
# 4         1       43633                  5          1

# %%
print(order_products_prior.shape)
order_products_prior.head()
# Out:
# (32434489, 4)
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
print(orders.shape)
orders.head()
# Out:
# (3421083, 7)
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
print(products.shape)
products.head()
# Out:
# (49688, 4)
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id
# 0             19
# 1             13
# 2              7
# 3              1
# 4             13

# %%
print(aisles.shape)
aisles.head()
# Out:
# (134, 2)
#    aisle_id                       aisle
# 0         1       prepared soups salads
# 1         2           specialty cheeses
# 2         3         energy granola bars
# 3         4               instant foods
# 4         5  marinades meat preparation

# %%
print(departments.shape)
departments.head()
# Out:
# (21, 2)
#    department_id department
# 0              1     frozen
# 1              2      other
# 2              3     bakery
# 3              4    produce
# 4              5    alcohol

# %%
# merging all the product info with aisle and deparment
product_info=products.merge(aisles,on='aisle_id').merge(departments,on='department_id')

# %%
product_info.head()
# Out:
#    product_id                                    product_name  aisle_id  \
# 0           1                      Chocolate Sandwich Cookies        61
# 1          78               Nutter Butter Cookie Bites Go-Pak        61
# 2         102                           Danish Butter Cookies        61
# 3         172  Gluten Free All Natural Chocolate Chip Cookies        61
# 4         285                    Mini Nilla Wafers Munch Pack        61
#
#    department_id          aisle department
# 0             19  cookies cakes     snacks
# 1             19  cookies cakes     snacks
# 2             19  cookies cakes     snacks
# 3             19  cookies cakes     snacks
# 4             19  cookies cakes     snacks

# %%
#merging train and test data
order_product_all=pd.concat([order_products_train, order_products_prior])
# order_product_all=order_product_all.merge(product_info,on='product_id')
order_product_all.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         1       49302                  1          1
# 1         1       11109                  2          1
# 2         1       10246                  3          0
# 3         1       49683                  4          0
# 4         1       43633                  5          1

# %% [markdown]
# ## Frequency of order by day of week

# %%
# Frequency of order by weekday
orders.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
day_order = ["Sunday","Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday"]
dow=orders['order_dow'].value_counts()

plt.bar(day_order,dow,tick_label=day_order, color='xkcd:azure')
# plt.title('Frequency of order by day of week')
plt.ylabel('orders')
plt.gca().tick_params(axis='x',rotation=30)
plt.gca().spines['top'].set_visible(False)
plt.savefig('instacart_fig/Daily.png', bbox_inches='tight', transparent=True)

# %% [markdown]
# ## Frequency of orders by hour

# %%
hour=orders['order_hour_of_day'].value_counts().sort_index()

plt.figure(figsize=(10,5))
plt.bar(hour.index,hour, color='xkcd:azure')
# plt.title('Frequency of orders by hour')
plt.ylabel('orders')
plt.gca().spines['top'].set_visible(False)
plt.xticks(hour.index)
plt.savefig('instacart_fig/Hour.png', bbox_inches='tight', transparent=True)

# %% [markdown]
# ## The number of orders by day of week x hour

# %%
grouped_df = orders.groupby(["order_dow", "order_hour_of_day"])["order_number"].aggregate("count").reset_index()
grouped_df = grouped_df.pivot('order_dow', 'order_hour_of_day', 'order_number')

plt.figure(figsize=(12,7))
fig=sns.heatmap(grouped_df, yticklabels=day_order, cmap="YlGnBu", square=True, cbar_kws={"shrink": .5})
plt.title("Orders of Day of week and Hour of day")
plt.xlabel('Hour of day')
plt.ylabel('Day of week')
plt.savefig('instacart_fig/dayhour.png', bbox_inches='tight', transparent=True)

# %% [markdown]
# ## Days since prior order

# %%
orders.head()
hour=orders['days_since_prior_order'].value_counts().sort_index()

plt.figure(figsize=(10,5))
plt.bar(hour.index,hour, color='xkcd:azure')
plt.title('Days since prior order')
plt.ylabel('Number of orders')
plt.xticks(hour.index)
plt.savefig('instacart_fig/dayssince.png', bbox_inches='tight', transparent=True)

# %% [markdown]
# ## Percentage of reorders

# %%
all_df=order_product_all.copy()
reorder=all_df['reordered'].value_counts()
colors=['xkcd:coral','xkcd:azure']

plt.figure(figsize=(10,5))
plt.pie(reorder, labels=['not-reordered','reordered'],colors=colors, autopct='%1.0f%%')
plt.title('Reorder percentage')
plt.savefig('instacart_fig/reorder.png', bbox_inches='tight', transparent=True)

# %% [markdown]
# ## Most popular items

# %%
product_df=order_product_all.merge(products,on='product_id')

# %%
bestitem=product_df['product_name'].value_counts().head(20).reset_index()
bestitem.columns=['product','count']

# %%
fig=sns.catplot(x='count',y='product',kind='bar',data=bestitem, aspect=2.5, legend_out=True)
fig.set_xticklabels(rotation=30)
plt.title('Most bought 20 items')
plt.savefig('instacart_fig/popularitems.png', bbox_inches='tight', transparent=True)

# %% [markdown]
# ## Most reordered items

# %%
best_reordered=product_df[product_df['reordered']==1]['product_name'].value_counts().head(20).reset_index()
best_reordered.columns=['product','count']

# %%
fig=sns.catplot(x='count',y='product',kind='bar',data=best_reordered, aspect=2.5, legend_out=True)
fig.set_xticklabels(rotation=30)
plt.title('Most reordered 20 items')
plt.savefig('instacart_fig/reorder.png', bbox_inches='tight', transparent=True)

# %% [markdown]
# ## Aisle and Department

# %%
aisle_df=product_df.merge(aisles,on='aisle_id')

# %%
bestaisle=aisle_df['aisle'].value_counts().head(20).reset_index()
bestaisle.columns=['aisle','count']
bestaisle.head()
# Out:
#                         aisle    count
# 0                fresh fruits  3792661
# 1            fresh vegetables  3568630
# 2  packaged vegetables fruits  1843806
# 3                      yogurt  1507583
# 4             packaged cheese  1021462

# %%
fig=sns.catplot(x='count',y='aisle',kind='bar',data=bestaisle, aspect=2.5, legend_out=True)
plt.title('Most bought 20 aisles')
plt.savefig('instacart_fig/popularaisles.png', bbox_inches='tight', transparent=True)

# %%
dept_df=product_df.merge(departments,on='department_id')
bestdept=dept_df['department'].value_counts().head(20).reset_index()
bestdept.columns=['dept','count']
bestdept.head()
# Out:
#          dept    count
# 0     produce  9888378
# 1  dairy eggs  5631067
# 2      snacks  3006412
# 3   beverages  2804175
# 4      frozen  2336858

# %%
fig=sns.catplot(x='count',y='dept',kind='bar',data=bestdept, aspect=2.5, legend_out=True)
plt.title('Most bought 20 depts')
plt.savefig('instacart_fig/populardepts.png', bbox_inches='tight', transparent=True)

# %% [markdown]
# # Association Rules Generation from Frequent Itemsets

# %% [markdown]
# An association rule is an implication expression of the form X→Y, where X and Y are disjoint itemsets. <br>A more concrete example based on consumer behaviour would be {Diapers}→{Beer} suggesting that people who buy diapers are also likely to buy beer. To evaluate the "interest" of such an association rule, different metrics have been developed. The current implementation make use of the confidence and lift metrics.
#
# ## Metrics
#
# (1) 'support':<br>
# support(A→C) = support(A∪C),range: (0,1)
# <br><br>
# (2) 'confidence':<br>
# confidence(A→C) = support(A→C)/support(A), range: (0,1)<br><br>
# The confidence of a rule A->C is the probability of seeing the consequent in a transaction given that it also contains the antecedent. Note that the metric is not symmetric or directed; for instance, the confidence for A->C is different than the confidence for C->A. The confidence is 1 (maximal) for a rule A->C if the consequent and antecedent always occur together.<br><br>
# (3) 'lift':<br>
# lift(A→C) = confidence(A→C)/support(C), range: (0,∞)<br><br>
# The lift metric is commonly used to measure how much more often the antecedent and consequent of a rule A->C occur together than we would expect if they were statistically independent. If A and C are independent, the Lift score will be exactly 1.

# %%
# including only reordered products

reordered=order_product_all[order_product_all['reordered']==1].merge(products,on='product_id')

# %%
reordered.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered      product_name  \
# 0         1       49302                  1          1  Bulgarian Yogurt
# 1    816049       49302                  7          1  Bulgarian Yogurt
# 2   1242203       49302                  1          1  Bulgarian Yogurt
# 3   1383349       49302                 11          1  Bulgarian Yogurt
# 4   2445303       49302                  2          1  Bulgarian Yogurt
#
#    aisle_id  department_id
# 0       120             16
# 1       120             16
# 2       120             16
# 3       120             16
# 4       120             16

# %%
reordered['order_id'].max()
# Out:
# 3421083

# %%
# including data whose order number is less than 50000
# since the data is so huge
df=reordered[reordered['order_id']<=50000]
# df=reordered

# %%
orderlist=df['order_id'].unique()
orderlist.size
# Out:
# 43040

# %%
df.head()
# Out:
#      order_id  product_id  add_to_cart_order  reordered  \
# 0           1       49302                  1          1
# 7       38841       49302                  5          1
# 108         1       11109                  2          1
# 215      1084       11109                  4          1
# 216      1175       11109                 14          1
#
#                                       product_name  aisle_id  department_id
# 0                                 Bulgarian Yogurt       120             16
# 7                                 Bulgarian Yogurt       120             16
# 108  Organic 4% Milk Fat Whole Milk Cottage Cheese       108             16
# 215  Organic 4% Milk Fat Whole Milk Cottage Cheese       108             16
# 216  Organic 4% Milk Fat Whole Milk Cottage Cheese       108             16

# %%
# Transforming data for mlxtend toolbox 
transaction=[]
for order in orderlist:
    temp=df[df['order_id']==order]['product_name'].to_list()
    transaction.append(temp)

# %%
from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder()
te_ary = te.fit(transaction).transform(transaction)
tsdata = pd.DataFrame(te_ary, columns=te.columns_)

# %%
tsdata.head()
# Out:
#    #2 Coffee Filters  #4 Natural Brown Coffee Filters  \
# 0              False                            False
# 1              False                            False
# 2              False                            False
# 3              False                            False
# 4              False                            False
#
#    & Go! Hazelnut Spread + Pretzel Sticks  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
#
#    0 Calorie Acai Raspberry Water Beverage  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
#
#    0% Fat Black Cherry Greek Yogurt y  0% Fat Blueberry Greek Yogurt  \
# 0                               False                          False
# 1                               False                          False
# 2                               False                          False
# 3                               False                          False
# 4                               False                          False
#
#    0% Fat Free Organic Milk  0% Fat Greek Yogurt Black Cherry on the Bottom  \
# 0                     False                                           False
# 1                     False                                           False
# 2                     False                                           False
# 3                     False                                           False
# 4                     False                                           False
#
#    0% Fat Greek Yogurt Vanilla  0% Fat Organic Greek Vanilla Yogurt  ...  \
# 0                        False                                False  ...
# 1                        False                                False  ...
# 2                        False                                False  ...
# 3                        False                                False  ...
# 4                        False                                False  ...
#
#    with Crispy Almonds Cereal  with Olive Oil Mayonnaise  \
# 0                       False                      False
# 1                       False                      False
# 2                       False                      False
# 3                       False                      False
# 4                       False                      False
#
#    with Olive Oil Mayonnaise Dressing  \
# 0                               False
# 1                               False
# 2                               False
# 3                               False
# 4                               False
#
#    with Seasoned Roasted Potatoes Scrambled Eggs & Sausage  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    with Sweet & Smoky BBQ Sauce Cheeseburger Sliders  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    with Xylitol Cinnamon 18 Sticks Sugar Free Gum  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                           False
#
#    with Xylitol Minty Sweet Twist 18 Sticks Sugar Free Gum  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    with Xylitol Original Flavor 18 Sticks Sugar Free Gum  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    with Xylitol Watermelon Twist 18 Sticks Sugar Free Gum  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    with a Splash of Mango Coconut Water
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False
#
# [5 rows x 20745 columns]

# %%
from mlxtend.frequent_patterns import fpgrowth

frequent_item=fpgrowth(tsdata, min_support=0.001, use_colnames=True)
frequent_item['length'] = frequent_item['itemsets'].apply(lambda x: len(x))

#the number of entire transaction is 8643
#threshold is >25

# %%
frequent_item.shape
# Out:
# (2209, 3)

# %%
frequent_item=frequent_item.sort_values(by=['support'],ascending=False)
frequent_item.head()
# Out:
#       support                  itemsets  length
# 28   0.141148                  (Banana)       1
# 1    0.112732  (Bag of Organic Bananas)       1
# 46   0.071445    (Organic Strawberries)       1
# 59   0.067542    (Organic Baby Spinach)       1
# 124  0.060223    (Organic Hass Avocado)       1

# %%
from mlxtend.frequent_patterns import association_rules

association=association_rules(frequent_item, metric="confidence", min_threshold=0.001)
association['Alength'] = association['antecedents'].apply(lambda x: len(x))
association['Clength'] = association['consequents'].apply(lambda x: len(x))

# %%
association=association.sort_values(by='lift',ascending=False)
association.head()
# Out:
#                                             antecedents  \
# 1919  (Total 2% Lowfat Greek Strained Yogurt With Bl...
# 1914  (Total 2% with Strawberry Lowfat Greek Straine...
# 1918  (Total 2% Lowfat Greek Strained Yogurt with Pe...
# 1915  (Total 2% with Strawberry Lowfat Greek Straine...
# 935                          (Non Fat Raspberry Yogurt)
#
#                                             consequents  antecedent support  \
# 1919  (Total 2% with Strawberry Lowfat Greek Straine...            0.005669
# 1914  (Total 2% Lowfat Greek Strained Yogurt With Bl...            0.002300
# 1918  (Total 2% with Strawberry Lowfat Greek Straine...            0.005019
# 1915  (Total 2% Lowfat Greek Strained Yogurt with Pe...            0.002718
# 935     (Icelandic Style Skyr Blueberry Non-fat Yogurt)            0.003996
#
#       consequent support   support  confidence       lift  leverage  \
# 1919            0.002300  0.001185    0.209016  90.869349  0.001172
# 1914            0.005669  0.001185    0.515152  90.869349  0.001172
# 1918            0.002718  0.001185    0.236111  86.856600  0.001171
# 1915            0.005019  0.001185    0.435897  86.856600  0.001171
# 935             0.004833  0.001673    0.418605  86.618962  0.001654
#
#       conviction  Alength  Clength
# 1919    1.261341        1        2
# 1914    2.050807        2        1
# 1918    1.305532        1        2
# 1915    1.763831        2        1
# 935     1.711688        1        1

# %% [markdown]
# ## Function for printing out top 5 items most bought together

# %%
# print top 5 items which have highest lift
def big5(basket):
    for item in basket:
        single=association[association['antecedents'].apply(lambda x: item in x) & association['Alength']==1][['antecedents','consequents','lift']][:5]
        double=association[association['antecedents'].apply(lambda x: item in x)][['antecedents','consequents','lift']][:5]
        return pd.concat([single,double],axis=0)

# %%
big5(['Banana'])
# Out:
#                     antecedents                            consequents  \
# 1675                   (Banana)        (Organic Avocado, Strawberries)
# 2351                   (Banana)            (Large Lemon, Strawberries)
# 1873                   (Banana)    (Organic Avocado, Honeycrisp Apple)
# 984                    (Banana)  (Organic Avocado, Organic Whole Milk)
# 1155                   (Banana)      (Organic Avocado, Cucumber Kirby)
# 1710      (Banana, Large Lemon)                       (Cucumber Kirby)
# 1319            (Banana, Limes)                          (Large Lemon)
# 489       (Banana, Large Lemon)                      (Organic Avocado)
# 1035            (Banana, Limes)                      (Organic Avocado)
# 1152  (Banana, Organic Avocado)                       (Cucumber Kirby)
#
#           lift
# 1675  3.385644
# 2351  3.291915
# 1873  3.226102
# 984   3.203942
# 1155  3.111556
# 1710  5.373220
# 1319  5.200786
# 489   4.975965
# 1035  4.649957
# 1152  4.580973

# %%
# replace frozenset to string
lift=association.copy()
lift['antecedents']=lift['antecedents'].apply(lambda x: ', '.join(list(x))).astype("unicode")
lift['consequents']=lift['consequents'].apply(lambda x: ', '.join(list(x))).astype("unicode")

# %%
# make a new column including sorted list of ant and cons
lift['pair']=lift.apply(lambda row: ', '.join(sorted([row.antecedents,row.consequents])), axis=1)

# %%
lift['label']=lift.apply(lambda row: '---'.join(sorted([row.antecedents,row.consequents])), axis=1)

# %%
df=lift[lift['Alength']==1].drop_duplicates(subset='pair',keep='first').head(20)
df=df[['antecedents','consequents','lift','confidence','label']]
df
# Out:
#                                             antecedents  \
# 1919  Total 2% Lowfat Greek Strained Yogurt With Blu...
# 1918   Total 2% Lowfat Greek Strained Yogurt with Peach
# 935                            Non Fat Raspberry Yogurt
# 1917  Total 2% with Strawberry Lowfat Greek Strained...
# 1940                         Vanilla Skyr Nonfat Yogurt
# 1343                         Vanilla Skyr Nonfat Yogurt
# 943    Total 2% Lowfat Greek Strained Yogurt with Peach
# 371   Total 2% Lowfat Greek Strained Yogurt With Blu...
# 534   Total 2% with Strawberry Lowfat Greek Strained...
# 1238  Total 2% Lowfat Greek Strained Yogurt With Blu...
# 1662   Total 2% Lowfat Greek Strained Yogurt with Peach
# 1527                               Lime Sparkling Water
# 2277                                               Soda
# 1402  Total 2% with Strawberry Lowfat Greek Strained...
# 2055  Total 2% All Natural Greek Strained Yogurt wit...
# 1207  Total 2% All Natural Greek Strained Yogurt wit...
# 1528                         Sparkling Water Grapefruit
# 550                                Lime Sparkling Water
# 2344                         Organic Whole Strawberries
# 1268                                        Raspberries
#
#                                             consequents       lift  \
# 1919  Total 2% with Strawberry Lowfat Greek Strained...  90.869349
# 1918  Total 2% with Strawberry Lowfat Greek Strained...  86.856600
# 935       Icelandic Style Skyr Blueberry Non-fat Yogurt  86.618962
# 1917  Total 2% Lowfat Greek Strained Yogurt With Blu...  85.636704
# 1940                           Non Fat Raspberry Yogurt  69.509044
# 1343      Icelandic Style Skyr Blueberry Non-fat Yogurt  68.974359
# 943   Total 2% Lowfat Greek Strained Yogurt With Blu...  58.797814
# 371   Total 2% with Strawberry Lowfat Greek Strained...  57.972002
# 534    Total 2% Lowfat Greek Strained Yogurt with Peach  55.411985
# 1238  Total 2% Greek Strained Yogurt with Cherry 5.3 oz  53.945567
# 1662  Total 2% Greek Strained Yogurt with Cherry 5.3 oz  52.233010
# 1527  Sparkling Water Grapefruit, Sparkling Lemon Water  42.598798
# 2277                                  Zero Calorie Cola  41.616884
# 1402  Total 2% Greek Strained Yogurt with Cherry 5.3 oz  34.626377
# 2055  Total 2% Lowfat Greek Strained Yogurt With Blu...  34.140666
# 1207  Total 2% with Strawberry Lowfat Greek Strained...  31.199710
# 1528        Lime Sparkling Water, Sparkling Lemon Water  27.758787
# 550                               Sparkling Lemon Water  22.983936
# 2344                    Frozen Organic Wild Blueberries  21.362567
# 1268                                       Blackberries  20.939109
#
#       confidence                                              label
# 1919    0.209016  Total 2% Lowfat Greek Strained Yogurt With Blu...
# 1918    0.236111  Total 2% Lowfat Greek Strained Yogurt with Pea...
# 935     0.418605  Icelandic Style Skyr Blueberry Non-fat Yogurt-...
# 1917    0.143258  Total 2% Lowfat Greek Strained Yogurt With Blu...
# 1940    0.277778  Non Fat Raspberry Yogurt---Vanilla Skyr Nonfat...
# 1343    0.333333  Icelandic Style Skyr Blueberry Non-fat Yogurt-...
# 943     0.333333  Total 2% Lowfat Greek Strained Yogurt With Blu...
# 371     0.479508  Total 2% Lowfat Greek Strained Yogurt With Blu...
# 534     0.278090  Total 2% Lowfat Greek Strained Yogurt with Pea...
# 1238    0.258197  Total 2% Greek Strained Yogurt with Cherry 5.3...
# 1662    0.250000  Total 2% Greek Strained Yogurt with Cherry 5.3...
# 1527    0.113821  Lime Sparkling Water---Sparkling Water Grapefr...
# 2277    0.109264                           Soda---Zero Calorie Cola
# 1402    0.165730  Total 2% Greek Strained Yogurt with Cherry 5.3...
# 2055    0.193548  Total 2% All Natural Greek Strained Yogurt wit...
# 1207    0.258065  Total 2% All Natural Greek Strained Yogurt wit...
# 1528    0.063205  Lime Sparkling Water, Sparkling Lemon Water---...
# 550     0.199187       Lime Sparkling Water---Sparkling Lemon Water
# 2344    0.147910  Frozen Organic Wild Blueberries---Organic Whol...
# 1268    0.105085                         Blackberries---Raspberries

# %% [markdown]
# ## Top 20 item pairs by lift metric

# %%
# modifying labels for visualization
labels=df['label']
labels = [ '\n'.join(wrap(l, 60)) for l in labels ]

# spacing btw bars
y_pos = np.arange(0,30,1.5)

# drawing pictures
plt.figure(figsize=(10,15))
plt.barh(y_pos,df['lift'],color='xkcd:azure')
plt.yticks(y_pos,labels)
plt.title('Top 20 itemsets by lift')
plt.xlabel('lift')
plt.gca().invert_yaxis()
plt.savefig('instacart_fig/topliftitemset.png', bbox_inches='tight', transparent=True)

# %% [markdown]
# ## Top 50 lift items and their relationships

# %%
#   
# ------- DIRECTED
 
# Build a dataframe with your connections

# df=lift.drop_duplicates(subset='pair',keep='first').head(50) 
df=lift[lift['Alength']==1].drop_duplicates(subset='pair',keep='first').head(50)
df=df[['antecedents','consequents','lift','confidence','label']]


# Build your graph. Note that we use the DiGraph function to create the graph!
G=nx.from_pandas_edgelist(df, 'antecedents', 'consequents', create_using=nx.DiGraph() )
 
# Make the graph
plt.figure(figsize=(30,30))
nx.draw(G, with_labels=True,node_size=2000, node_color='#A0CBE2',alpha=1, edge_color=df['lift'].to_list(),width=4, edge_cmap=plt.cm.Blues)
# plt.savefig('instacart_fig/network.png', bbox_inches='tight')

# %% [markdown]
# ## Top 50 lift items and their relationships by departments

# %%
df=lift[(lift['Alength']==1) & (lift['Clength']==1)].drop_duplicates(subset='pair',keep='first')

# %%
df=pd.merge(df[['antecedents','consequents','lift']], product_info[['product_name','department']], left_on=  ['antecedents'],
                   right_on= ['product_name'], 
                   how = 'left')
df['Adept']=df['department']
df=pd.merge(df[['antecedents','consequents','lift','Adept']], product_info[['product_name','department']], left_on=  ['consequents'],
                   right_on= ['product_name'], 
                   how = 'left')
df['Cdept']=df['department']
df=df[['antecedents','consequents','lift','Adept','Cdept']].head(50)

# %%
# Build a dataframe with your connections
# df = pd.DataFrame({ 'from':['A', 'B', 'C','A'], 'to':['D', 'A', 'E','C']})
 
# And a data frame with characteristics for your nodes
# carac = pd.DataFrame({ 'ID':['A', 'B', 'C','D','E'], 'myvalue':['group1','group1','group2','group3','group3'] })
carac = product_info[['product_name','department']] 

# Build your graph
G=nx.from_pandas_edgelist(df, 'antecedents', 'consequents', create_using=nx.DiGraph() )
 
# The order of the node for networkX is the following order:
G.nodes()
# Thus, we cannot give directly the 'myvalue' column to netowrkX, we need to arrange the order!
 
# Here is the tricky part: I need to reorder carac to assign the good color to each node
carac= carac.set_index('product_name')
carac=carac.reindex(G.nodes())
 
# And I need to transform my categorical column in a numerical value: group1->1, group2->2...
carac['myvalue']=pd.Categorical(carac['department'])
carac['myvalue'].cat.codes
 
# Custom the nodes:
plt.figure(figsize=(30,30))
nx.draw(G, with_labels=True, node_color=carac['myvalue'].cat.codes, cmap=plt.cm.Set1, node_size=1500)
plt.savefig('instacart_fig/network_depts.png', bbox_inches='tight', transparent=True)
